# %% [markdown]
# ## Load and Compile Data

# %% [markdown]
# **Importing required libraries**

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import os
import numpy as np

DATA_PATH = '../data/vrd_data/'

# %% [markdown]
# We can inspect the datasets one at a time to ensure consistent setup. First we get all the datasets for convenience. Tournaments with same letter prefix follow the same data setup.

# %%
filenames = []
for (dirpath, dirname, filename) in os.walk(DATA_PATH):
    filenames.extend(filename)
    break
filenames
# Out:
# ['extras.csv',
#  'VRD Archives - ALEX1.csv',
#  'VRD Archives - CHI1.csv',
#  'VRD Archives - CHI2.csv',
#  'VRD Archives - CHI3.csv',
#  'VRD Archives - DIS1.csv',
#  'VRD Archives - DIS10.csv',
#  'VRD Archives - DIS11.csv',
#  'VRD Archives - DIS12.csv',
#  'VRD Archives - DIS13.csv',
#  'VRD Archives - DIS2.csv',
#  'VRD Archives - DIS3.csv',
#  'VRD Archives - DIS4.csv',
#  'VRD Archives - DIS8.csv',
#  'VRD Archives - DIS9.csv',
#  'VRD Archives - GG1.csv',
#  'VRD Archives - MT1.csv',
#  'VRD Archives - MT2.csv',
#  'VRD Archives - MT3.csv',
#  'VRD Archives - NWVRD2.csv',
#  'VRD Archives - NWVRD3.csv',
#  'VRD Archives - NWVRD4.csv',
#  'VRD Archives - NWVRD5.csv',
#  'VRD Archives - NWVRD6.csv',
#  'VRD Archives - NWVRD7.csv',
#  'VRD Archives - NWVRD8.csv',
#  'VRD Archives - OCL3.csv',
#  'VRD Archives - PDX1.csv',
#  'VRD Archives - PDX2.csv',
#  'VRD Archives - PDX3.csv',
#  'VRD Archives - PDX4.csv',
#  'VRD Archives - SFL1.csv',
#  'VRD Archives - StLotus1.csv',
#  'VRD Archives - StLotus2.csv',
#  'VRD Archives - StLotus3.csv',
#  'VRD Archives - StLotus4.csv',
#  'VRD Archives - StLotus5.csv',
#  'VRD Archives - StLotus7.csv',
#  'VRD Archives - StLotus8.csv',
#  'VRD Archives - STLPresents1.csv',
#  'VRD Archives - TAN2.csv',
#  'VRD Archives - VIC8.csv',
#  'VRD Archives - WIN1.csv',
#  'VRD Archives - WIN2.csv',
#  'VRD Archives - WIN3.csv',
#  'VRD Archives - WIN4.csv',
#  'VRD Archives - WIN7.csv',
#  'VRD Archives - YYZ1.csv']

# %%
df = pd.read_csv(DATA_PATH + 'VRD Archives - ALEX1.csv')
df
# Out:
#    Unnamed: 0                                                 JB  \
# 0        Wins                                                  2
# 1      Losses                                                  5
# 2        Date                                         2014-12-17
# 3       Notes  this came from some guy posting on a forum abo...
# 4           1                                        Black Lotus
# 5           2                                      Force of Will
# 6           3                                           Sol Ring
# 7           4                            Jace, the Mind Sculptor
# 8           5                                  True-Name Nemesis
# 9           6                                      Scalding Tarn
# 10          7                                          Preordain
# 11          8                                     Polluted Delta
# 12          9                                     Dark Confidant
# 13         10                                               gush
# 14         11                                          Mana Leak
# 15         12                                    Volcanic Island
# 16         13                                   Young Pyromancer
# 17         14                                        Steam Vents
# 18         15                                     Miscalculation
# 19         16                                     Steel Sabotage
# 20         17                                      Serum Visions
# 21         18                                    Underground Sea
# 22         19                                    Yawgmoth's Will
# 23         20                                   Disrupting Shoal
# 24         21                                     Gitaxian Probe
# 25         22                                           Badlands
# 26         23                                             Negate
# 27         24                                        Izzet Charm
# 28         25                                          Dismember
# 29         26                                      Baleful Strix
# 30         27                                Relic of Progenitus
# 31         28                                   Drowned Catacomb
# 32         29                                    Faerie Conclave
# 33         30                                       Cunning Wish
# 34         31                                Surgical Extraction
# 35         32                                         Doom Blade
# 36         33                                  Grafdigger's Cage
# 37         34                              Engineered Explosives
# 38         35                                              Annul
# 39         36                                        Forked bolt
# 40         37                                      Echoing Truth
# 41         38                                              Smelt
# 42         39                                        Counterflux
# 43         40                                        fire // ice
# 44         41                                          Rune Snag
# 45         42                                        far // away
# 46         43                                  Nightveil Specter
# 47         44                                   Darkslick Shores
# 48         45                                       Notion Thief
#
#                                  JW                         AW  \
# 0                                 2                          6
# 1                                 5                          1
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                      Mox Sapphire                    Mox Jet
# 5                        time vault                 Strip Mine
# 6                       voltaic key                  Wasteland
# 7                 stoneforge mystic                 Mana Vault
# 8                       batterskull     Inquisition of Kozilek
# 9              blightsteel colossus      Sensei's Divining Top
# 10                        swan song              Natural Order
# 11          emrakul, the aeons torn             Vampiric Tutor
# 12                    imperial seal          Birds of Paradise
# 13                   oath of druids            Woodfall Primus
# 14                forbidden orchard               Animate Dead
# 15                  gaea's blessing            Hymn to Tourach
# 16                 city of solitude         Green Sun's Zenith
# 17                            bayou           Reclamation Sage
# 18                  tropical island             Overgrown Tomb
# 19                           tundra            Windswept Heath
# 20                         savannah                Marsh Flats
# 21                        fade away            Worldspine Wurm
# 22                 wooded foothills               Fauna Shaman
# 23  the tabernacle at pendrell vale      Thrun, the Last Troll
# 24                       progenitus                    Putrefy
# 25                   constant mists             Diabolic Edict
# 26                           tangle                 Terastodon
# 27                       dawn charm            Llanowar Wastes
# 28                   moment's peace                     Eureka
# 29                    show and tell  Boseiju, who shelters all
# 30                          respite            Scavenging Ooze
# 31                 isochron scepter                 MInd twist
# 32                    academy ruins             Mesmeric Fiend
# 33                     beast within          Woodland Cemetery
# 34                   tormod's crypt              Twilight Mire
# 35                   nature's claim                    Crumble
# 36                      energy flux               Tainted Wood
# 37                       forcefield             Fyndhorn Elves
# 38                   expedition map          Sylvan Primordial
# 39                    homeward path             Slaughter Pact
# 40              rapid hybridization             Llanowar Elves
# 41            elixir of immortality   Urborg, Tomb of Yawgmoth
# 42                          pongify          Guttural Response
# 43                  fact or fiction             Faerie Macabre
# 44                     riot control             Vexing Shusher
# 45                             moat                      Choke
# 46                         holy day              Autumn's Veil
# 47                    cyclonic rift                  Harmonize
# 48                              fog        Elvish Spirit Guide
#
#                            DL                           JG  \
# 0                           5                            3
# 1                           2                            4
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                   Mox Pearl             Ancestral Recall
# 5                      Tinker                    Time Walk
# 6         Tezzeret the Seeker              Snapcaster Mage
# 7                  Mana Crypt                 Spell Pierce
# 8               grim monolith                   Brainstorm
# 9                 timetwister               Mental Misstep
# 10             mystical tutor                         Daze
# 11          enlightened tutor                  Spell Snare
# 12            basalt monolith             Misty Rainforest
# 13           tolarian academy          Spellstutter Sprite
# 14                metalworker                 Counterspell
# 15                Mox diamond            Vedalken Shackles
# 16               trinket mage               Flooded Strand
# 17                     dispel       Thada Adel, Acquisitor
# 18                   Upheaval                      Bribery
# 19             Personal Tutor              Cryptic Command
# 20                Force Spike        Venser, Shaper Savant
# 21           city of traitors            Hallowed Fountain
# 22  kozilek, butcher of truth             Phantasmal Image
# 23                     remand         Swords to Plowshares
# 24                    balance                  Aether Vial
# 25               misdirection                    Mutavault
# 26              path to exile                 Flusterstorm
# 27               defense grid                 Cursecatcher
# 28          inkwell leviathan           Containment Priest
# 29                    gainsay                Rest in Peace
# 30       thirst for knowledge            Helm of Obedience
# 31         muddle the mixture                 Gilded Drake
# 32                    disrupt          Celestial Colonnade
# 33                Tangle Wire           Kataki, war's wage
# 34                   Mox opal              supreme verdict
# 35             karn liberated              Merrow Reejerey
# 36    temple of enlightenment              seachrome coast
# 37                 chrome mox                arcane denial
# 38             power artifact        Sygg, River cutthroat
# 39          seat of the synod        Talrand, Sky Summoner
# 40              tidal control              Master of Waves
# 41                Ancient Den  master of the Pearl trident
# 42           Stroke of Genius         geist of saint traft
# 43                    Channel             Glacial Fortress
# 44               pentad prism        Timely Reinforcements
# 45            lodestone golem                  Mystic Gate
# 46                     repeal   Jace, Architect of thought
# 47             chromatic star                 Jace Beleren
# 48              tree of tales              Calciform Pools
#
#                                            SW                            MT  \
# 0                                           5                             1
# 1                                           2                             6
# 2                                         NaN                           NaN
# 3                                         NaN                           NaN
# 4                                    Mox Ruby                   Mox Emerald
# 5                                  Skullclamp                      Fastbond
# 6                            Ancestral Vision             Mishra's Workshop
# 7                                  Mana Drain             bazaar of baghdad
# 8                             Umezawa's Jitte            crucible of worlds
# 9                            Vendilion Clique                  ancient tomb
# 10                               Memory Lapse                 crop rotation
# 11  Delver of Secrets // Insectile Aberration                 inkmoth nexus
# 12                        Red Elemental Blast                   dark depths
# 13                                  Pyroblast              thespian's stage
# 14                            Treasure Cruise            life from the loam
# 15                           Dig Through Time                     zuran orb
# 16                        Goblin Rabblemaster                      land tax
# 17                                     Ponder                horizon canopy
# 18                               Goblin Guide                   maze of ith
# 19                                Dack Fayden                       karakas
# 20                                 Standstill                Primeval titan
# 21                             Lightning Bolt               Eternal Witness
# 22                                   Prohibit                   exploration
# 23                            Chain Lightning              Mistcutter hydra
# 24                      Sword of Fire and Ice       knight of the reliquary
# 25                          Phyrexian Revoker                sylvan library
# 26                          Magus of the Moon                     arid mesa
# 27                             Cascade Bluffs                    armageddon
# 28                               Sulfur Falls                         taiga
# 29                                Electrolyze                       plateau
# 30                                    Deprive                   krosan grip
# 31                             Pithing Needle              qasali pridemage
# 32                                   Null Rod                      banefire
# 33                           Shattering Spree                    scapeshift
# 34                                 Pestermite   thalia, guardian of thraben
# 35                              Splinter Twin  valakut, the molten pinnacle
# 36                            Deceiver Exarch                prismatic omen
# 37                  Kiki-Jiki, Mirror Breaker                 ghost quarter
# 38                                  Rift Bolt                   lotus cobra
# 39                         Koth of the Hammer           avenger of zendikar
# 40                               Sudden Shock      grove of the burnwillows
# 41                    Teferi, Mage of Zhalfir                punishing fire
# 42                           Volcanic Fallout                sylvan scrying
# 43                                    Envelop                      manabond
# 44                                 Skullcrack                 horn of greed
# 45                   Flames of the Blood Hand         wheel of sun and moon
# 46                        Clever Impersonator                  genesis wave
# 47                         Hero of Oxid Ridge         bonfire of the damned
# 48                         Liquimetal Coating          CREEPING RENAISSANCE
#
#                          AP
# 0                         4
# 1                         3
# 2                       NaN
# 3                       NaN
# 4     LIBRARY OF ALEXANDRIA
# 5             DEMONIC TUTOR
# 6              THOUGHTSEIZE
# 7                    ENTOMB
# 8                    DURESS
# 9               DARK RITUAL
# 10  SURVIVAL OF THE FITTEST
# 11        PAINTER'S SERVANT
# 12         DEATHRITE SHAMAN
# 13              GRISELBRAND
# 14                REANIMATE
# 15         BANE OF PROGRESS
# 16             ABRUPT DECAY
# 17            GOLGARI CHARM
# 18        VERDANT CATACOMBS
# 19      LILIANA OF THE VEIL
# 20                   EXHUME
# 21        BLOODSTAINED MIRE
# 22             NECROPOTENCE
# 23      PHYREXIAN METAMORPH
# 24      RECURRING NIGHTMARE
# 25   IONA, SHIELD OF EMERIA
# 26              LOTUS PETAL
# 27                 PACK RAT
# 28               NECROMANCY
# 29      LEYLINE OF THE VOID
# 30               GRINDSTONE
# 31                   UNMASK
# 32             BRAIN MAGGOT
# 33          MAELSTROM PULSE
# 34                TARMOGOYF
# 35          STOMPING GROUND
# 36              BLOOD CRYPT
# 37               BLOODGHAST
# 38          PERNICIOUS DEED
# 39             TOXIC DELUGE
# 40              ASHEN RIDER
# 41        KRUPHIX'S INSIGHT
# 42               BLIGHTNING
# 43           BLOODBRAID ELF
# 44                 SINKHOLE
# 45            SHALLOW GRAVE
# 46              NICOL BOLAS
# 47        GO FOR THE THROAT
# 48      SQUEE, GOBLIN NABOB

# %% [markdown]
# **Define dataframe colums.**
# We will add more columns later.

# %%
column_names = ['card_name', 'tournament_id', 'date', 'player_id', 'player_idx', 'round_idx', 'deck_wins', 'deck_losses']

df = pd.DataFrame(columns = column_names)

for column in df.columns:
    print(column)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [217], in <cell line: 5>()
#       3 df = pd.DataFrame(columns = column_names)
#       5 for column in df.columns:
# ----> 6     print(column[:, 1:])
#
# TypeError: string indices must be integers

# %% [markdown]
# Due to similar setup we can loop through all of the libraries in order.

# %%
for file in os.listdir(DATA_PATH):
    if file.startswith('VRD Archives - '):
        
        # 12 players in this data which would skew the results
        if file == 'VRD Archives - CHI1.csv': continue
        
        # Get tournament id
        tournament_id = file.split(' - ')[1].replace('.csv', '')
        print(tournament_id)
        
        tmp_df = pd.read_csv(DATA_PATH + file)
        
        # Get date
        date = tmp_df[tmp_df.iloc[:, 0].str.contains('Date', na=False, case=False)].iloc[:, 1].iloc[-1]                
        print(date)
        
        # Get player ids in an ordered list
        player_ids = list(tmp_df)[1:]
        print(player_ids)
        
        # Get player wins in an ordered list
        wins = tmp_df[tmp_df.iloc[:, 0].str.contains('Wins', na=False, case=False)].iloc[:, 1:].values[0] #unpack double list
        print(wins)
        
        # Get player losses in an ordered list
        losses = tmp_df[tmp_df.iloc[:, 0].str.contains('Losses', na=False, case=False)].iloc[:, 1:].values[0] #unpack double list
        print(losses)
        
        # Now we grab the card names and relative indexes. The cards are picked in order from left to right in the first row, 
        # and then every other row, and from the right to left otherwise, following a zig-zag pattern.
        # This can be added to the dataframe including the previously obtained data.
        
        # find index of the row with 1 in the first cell, that's where card selection begins
        start_row = tmp_df[tmp_df.iloc[:, 0]=='1'].index.values.astype(int)[0]
        
        # get a slice containing the drafted cards
        cards_df = tmp_df.iloc[start_row:,1:9].reset_index(drop=True)
        cards_df.index += 1 # make index equal to round
        cards_df = cards_df.applymap(lambda s: s.lower().strip() if type(s) == str else s)
        
        # Map player_ids to wins, losses, and player_idx:
        map_id = {player_ids[i]: player_ids.index(player_ids[i])+1 for i in range(len(player_ids))}
        map_id_rl = {player_ids[i]: [8, 7, 6, 5, 4, 3, 2, 1][i] for i in range(len(player_ids))}
        map_wins = {player_ids[i]: wins[i] for i in range(len(player_ids))}
        map_losses = {player_ids[i]: losses[i] for i in range(len(player_ids))}
        
        print(map_id_rl)
# Out:
# ALEX1
# 2014-12-17
# ['JB', 'JW', 'AW', 'DL', 'JG', 'SW', 'MT', 'AP']
# ['2' '2' '6' '5' '3' '5' '1' '4']
# ['5' '5' '1' '2' '4' '2' '6' '3']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [292], in <cell line: 1>()
#      41 # Map player_ids to wins, losses, and player_idx:
#      42 map_id = {player_ids[i]: player_ids.index(player_ids[i])+1 for i in range(len(player_ids))}
# ---> 43 map_id_rl = {player_ids[i]: list(np.arange(1,8+1)).reverse()[i] for i in range(len(player_ids))}
#      44 map_wins = {player_ids[i]: wins[i] for i in range(len(player_ids))}
#      45 map_losses = {player_ids[i]: losses[i] for i in range(len(player_ids))}
#
# Input In [292], in <dictcomp>(.0)
#      41 # Map player_ids to wins, losses, and player_idx:
#      42 map_id = {player_ids[i]: player_ids.index(player_ids[i])+1 for i in range(len(player_ids))}
# ---> 43 map_id_rl = {player_ids[i]: list(np.arange(1,8+1)).reverse()[i] for i in range(len(player_ids))}
#      44 map_wins = {player_ids[i]: wins[i] for i in range(len(player_ids))}
#      45 map_losses = {player_ids[i]: losses[i] for i in range(len(player_ids))}
#
# TypeError: 'NoneType' object is not subscriptable

# %%
cards_df.head()
# Out:
#                       April                    David               Dom Reborn  \
# 1               black lotus         ancestral recall                 sol ring
# 2                  mox opal               mana vault            demonic tutor
# 3  emry, lurker of the loch            force of will           vampiric tutor
# 4         mishra's workshop  jace, the mind sculptor                  channel
# 5        transmute artifact             spell pierce  karn, the great creator
#
#                Alex         Jacob          Andrew                   Freyja  \
# 1        time vault  mox sapphire       mox pearl                  mox jet
# 2            tinker     time walk     mox diamond               mana crypt
# 3       timetwister   dack fayden        null rod    library of alexandria
# 4  tolarian academy    mana drain  mental misstep  survival of the fittest
# 5     grim monolith  sneak attack    cursed totem          prismatic vista
#
#                        Russel
# 1                 mox emerald
# 2                    mox ruby
# 3                  strip mine
# 4  eidolon of the great revel
# 5               wrenn and six

# %%
#['card_name', 'pick_idx', 'player_idx', 'round_idx', 'deck_wins', 'deck_losses', 'player_id', 'tournament_id', 'date',]
dfs = cards_df.stack().reset_index()
dfs['pick_idx'] = dfs.index + 1
dfs.rename(columns = {'level_0': 'round_idx', 0: 'card_name', 'level_1': 'player_id'}, inplace = True)
dfs['tournament_id'] = tournament_id
dfs['date'] = date
dfs['player_idx'] = dfs['player_id'].map(map_id)
dfs['deck_wins'] = dfs['player_id'].map(map_wins)
dfs['deck_losses'] = dfs['player_id'].map(map_losses)
dfs = dfs[['card_name', 'pick_idx', 'player_idx', 'round_idx', 'deck_wins', 'deck_losses', 'player_id', 'tournament_id', 'date']]
dfs.loc[dfs['round_idx']%2 == 0, 'pick_idx'] = dfs['round_idx']*
dfs
# Out:
#                         card_name  pick_idx  player_idx  round_idx deck_wins  \
# 0                     black lotus         1           1          1         1
# 1                ancestral recall         2           2          1         3
# 2                        sol ring         3           3          1         5
# 3                      time vault         4           4          1         1
# 4                    mox sapphire         5           5          1         0
# ..                            ...       ...         ...        ...       ...
# 355                  future sight       356           4         45         1
# 356  ulamog, the ceaseless hunger       357           5         45         0
# 357               secluded steppe       358           6         45         2
# 358                      seedtime       359           7         45         2
# 359                 ramunap ruins       360           8         45         5
#
#     deck_losses   player_id tournament_id        date
# 0             3       April          YYZ1  2020-04-11
# 1             3       David          YYZ1  2020-04-11
# 2             0  Dom Reborn          YYZ1  2020-04-11
# 3             2        Alex          YYZ1  2020-04-11
# 4             3       Jacob          YYZ1  2020-04-11
# ..          ...         ...           ...         ...
# 355           2        Alex          YYZ1  2020-04-11
# 356           3       Jacob          YYZ1  2020-04-11
# 357           3      Andrew          YYZ1  2020-04-11
# 358           4      Freyja          YYZ1  2020-04-11
# 359           1      Russel          YYZ1  2020-04-11
#
# [360 rows x 9 columns]
